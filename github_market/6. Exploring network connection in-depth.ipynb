# %% [markdown]
# # 0. Importing packages

# %%
# Load the autoreload extension to automatically reload modules before executing code (to avoid restarting the kernel)
# %load_ext autoreload 
# NB. uncomment the line above first time you run this cell
# %autoreload 2

# %%
from pathlib import Path
import pandas as pd
from typing import Dict
from tqdm import tqdm

from resources.filter_functions import look_company_up_in_edgelist
from resources.github_functions import GithubScraper


# Instantiate GithubScraper
gs = GithubScraper()
# Out:
# GithubScraper initialized with 3 tokens.
# First token in cycle. Initiating ACCESS_TOKEN_1.
# GithubScraper initialized with 0 companies and 0 users already scraped.

# %% [markdown]
# ## 0.1 File Paths

# %%
fp_main = Path('/Volumes/SAM-SODAS-DISTRACT/Coding Distraction/github_as_a_market_device')
fp_main_output = Path(fp_main / 'output')

# %% [markdown]
# # 1 Load in the data

# %%
# Read in the data
all_edges_user_level = pd.read_parquet(fp_main_output / 'all_edges_user_level.gzip.parquet')
attention_edges_user_level = pd.read_parquet(fp_main_output / 'attention_edges_user_level.gzip.parquet')
collaboration_edges_user_level = pd.read_parquet(fp_main_output / 'collaboration_edges_user_level.gzip.parquet')

# %%
mask = (collaboration_edges_user_level['src_company'] == 'trifork') | (collaboration_edges_user_level['target_company'] == 'trifork')
collaboration_edges_user_level[mask]
# Out:
#                     src             target src_company target_company  \
# 35           frjtrifork            trifork     trifork        trifork
# 36             bjarkehs            trifork     trifork        trifork
# 37           frjtrifork            trifork     trifork        trifork
# 38            MadsPoder            trifork     trifork        trifork
# 39        SebastianRask            trifork     trifork        trifork
# 40          LVH-trifork            trifork     trifork        trifork
# 41             bjarkehs            trifork     trifork        trifork
# 42           jhntrifork            trifork     trifork        trifork
# 437            madsthom           madsthom     trifork        trifork
# 438            madsthom           madsthom     trifork        trifork
# 460    AndersSpringborg    mathiasandresen     trifork        trifork
# 467              jacobe             jacobe     trifork        trifork
# 967            madsthom             mkholt     trifork     delegateas
# 986        JonasGLund99  anton-christensen  delegateas        trifork
# 987   anton-christensen  anton-christensen     trifork        trifork
# 988   anton-christensen  anton-christensen     trifork        trifork
# 990              jkiddo             jkiddo     trifork        trifork
# 991              jkiddo             jkiddo     trifork        trifork
# 992              jkiddo             jkiddo     trifork        trifork
# 993             trifork             jkiddo     trifork        trifork
# 994              jkiddo             jkiddo     trifork        trifork
# 995          fmotrifork             jkiddo     trifork        trifork
# 1000           bjarkehs         frjtrifork     trifork        trifork
# 1016               SDI8         mfrtrifork     trifork        trifork
# 1034        Strongminds            chrklin     trifork        trifork
# 1035         miracle-as            chrklin     miracle        trifork
# 1036        Strongminds            chrklin     trifork        trifork
# 1037          humleflue          humleflue     trifork        trifork
# 1040               hcnp               hcnp     trifork        trifork
# 1216            trifork      SebastianRask     trifork        trifork
# 1217           madsthom             mkholt     trifork     delegateas
# 1253   AndersSpringborg    mathiasandresen     trifork        trifork
# 2692               SDI8         mfrtrifork     trifork        trifork
# 2711         fmotrifork             jkiddo     trifork        trifork
# 2840        LVH-trifork            trifork     trifork        trifork
# 2841         frjtrifork            trifork     trifork        trifork
# 2842         frjtrifork            trifork     trifork        trifork
# 2917          MadsPoder            trifork     trifork        trifork
# 3075         jhntrifork            trifork     trifork        trifork
# 3076         jhntrifork      SebastianRask     trifork        trifork
# 3118      SebastianRask            trifork     trifork        trifork
#
#       src_company_category                      src_company_label  \
# 35                       1  1 Digital and marketing consultancies
# 36                       1  1 Digital and marketing consultancies
# 37                       1  1 Digital and marketing consultancies
# 38                       1  1 Digital and marketing consultancies
# 39                       1  1 Digital and marketing consultancies
# 40                       1  1 Digital and marketing consultancies
# 41                       1  1 Digital and marketing consultancies
# 42                       1  1 Digital and marketing consultancies
# 437                      1  1 Digital and marketing consultancies
# 438                      1  1 Digital and marketing consultancies
# 460                      1  1 Digital and marketing consultancies
# 467                      1  1 Digital and marketing consultancies
# 967                      1  1 Digital and marketing consultancies
# 986                      1  1 Digital and marketing consultancies
# 987                      1  1 Digital and marketing consultancies
# 988                      1  1 Digital and marketing consultancies
# 990                      1  1 Digital and marketing consultancies
# 991                      1  1 Digital and marketing consultancies
# 992                      1  1 Digital and marketing consultancies
# 993                      1  1 Digital and marketing consultancies
# 994                      1  1 Digital and marketing consultancies
# 995                      1  1 Digital and marketing consultancies
# 1000                     1  1 Digital and marketing consultancies
# 1016                     1  1 Digital and marketing consultancies
# 1034                     1  1 Digital and marketing consultancies
# 1035                     2                2 Bespoke app companies
# 1036                     1  1 Digital and marketing consultancies
# 1037                     1  1 Digital and marketing consultancies
# 1040                     1  1 Digital and marketing consultancies
# 1216                     1  1 Digital and marketing consultancies
# 1217                     1  1 Digital and marketing consultancies
# 1253                     1  1 Digital and marketing consultancies
# 2692                     1  1 Digital and marketing consultancies
# 2711                     1  1 Digital and marketing consultancies
# 2840                     1  1 Digital and marketing consultancies
# 2841                     1  1 Digital and marketing consultancies
# 2842                     1  1 Digital and marketing consultancies
# 2917                     1  1 Digital and marketing consultancies
# 3075                     1  1 Digital and marketing consultancies
# 3076                     1  1 Digital and marketing consultancies
# 3118                     1  1 Digital and marketing consultancies
#
#       target_company_category                   target_company_label  \
# 35                          1  1 Digital and marketing consultancies
# 36                          1  1 Digital and marketing consultancies
# 37                          1  1 Digital and marketing consultancies
# 38                          1  1 Digital and marketing consultancies
# 39                          1  1 Digital and marketing consultancies
# 40                          1  1 Digital and marketing consultancies
# 41                          1  1 Digital and marketing consultancies
# 42                          1  1 Digital and marketing consultancies
# 437                         1  1 Digital and marketing consultancies
# 438                         1  1 Digital and marketing consultancies
# 460                         1  1 Digital and marketing consultancies
# 467                         1  1 Digital and marketing consultancies
# 967                         1  1 Digital and marketing consultancies
# 986                         1  1 Digital and marketing consultancies
# 987                         1  1 Digital and marketing consultancies
# 988                         1  1 Digital and marketing consultancies
# 990                         1  1 Digital and marketing consultancies
# 991                         1  1 Digital and marketing consultancies
# 992                         1  1 Digital and marketing consultancies
# 993                         1  1 Digital and marketing consultancies
# 994                         1  1 Digital and marketing consultancies
# 995                         1  1 Digital and marketing consultancies
# 1000                        1  1 Digital and marketing consultancies
# 1016                        1  1 Digital and marketing consultancies
# 1034                        1  1 Digital and marketing consultancies
# 1035                        1  1 Digital and marketing consultancies
# 1036                        1  1 Digital and marketing consultancies
# 1037                        1  1 Digital and marketing consultancies
# 1040                        1  1 Digital and marketing consultancies
# 1216                        1  1 Digital and marketing consultancies
# 1217                        1  1 Digital and marketing consultancies
# 1253                        1  1 Digital and marketing consultancies
# 2692                        1  1 Digital and marketing consultancies
# 2711                        1  1 Digital and marketing consultancies
# 2840                        1  1 Digital and marketing consultancies
# 2841                        1  1 Digital and marketing consultancies
# 2842                        1  1 Digital and marketing consultancies
# 2917                        1  1 Digital and marketing consultancies
# 3075                        1  1 Digital and marketing consultancies
# 3076                        1  1 Digital and marketing consultancies
# 3118                        1  1 Digital and marketing consultancies
#
#       d_intra_level  d_inter_level  \
# 35                1              0
# 36                1              0
# 37                1              0
# 38                1              0
# 39                1              0
# 40                1              0
# 41                1              0
# 42                1              0
# 437               1              0
# 438               1              0
# 460               1              0
# 467               1              0
# 967               0              1
# 986               0              1
# 987               1              0
# 988               1              0
# 990               1              0
# 991               1              0
# 992               1              0
# 993               1              0
# 994               1              0
# 995               1              0
# 1000              1              0
# 1016              1              0
# 1034              1              0
# 1035              0              1
# 1036              1              0
# 1037              1              0
# 1040              1              0
# 1216              1              0
# 1217              0              1
# 1253              1              0
# 2692              1              0
# 2711              1              0
# 2840              1              0
# 2841              1              0
# 2842              1              0
# 2917              1              0
# 3075              1              0
# 3076              1              0
# 3118              1              0
#
#                                              edge_repo action  created_at
# 35                                     dgws/frjtrifork  forks  2012-05-10
# 36    fastlane-plugin-prepare_build_resources/bjarkehs  forks  2017-01-26
# 37                                      sdm/frjtrifork  forks  2012-03-02
# 38                                 the-vault/MadsPoder  forks  2019-09-16
# 39                           TIM-Android/SebastianRask  forks  2023-03-15
# 40                             TIM-Android/LVH-trifork  forks  2022-11-22
# 41                    TPA-fastlane-plugin-tpa/bjarkehs  forks  2018-08-06
# 42                   TriforkSwiftExtensions/jhntrifork  forks  2018-10-04
# 437                                      zapr/madsthom  forks  2017-12-01
# 438                             ngx-cron-jobs/madsthom  forks  2020-12-04
# 460                         uni-notes/AndersSpringborg  forks  2020-05-31
# 467                                     bmm-web/jacobe  forks  2023-03-22
# 967                  pcf-reloader-transformer/madsthom  forks  2022-07-06
# 986               DistributedExercisesAAU/JonasGLund99  forks  2024-09-25
# 987          DistributedExercisesAAU/anton-christensen  forks  2021-09-06
# 988                      imgur-heart/anton-christensen  forks  2015-02-20
# 990                                    pathling/jkiddo  forks  2023-10-28
# 991                                  ILCore-Git/jkiddo  forks  2023-12-04
# 992           hapi-fhir-forge-profile-converter/jkiddo  forks  2016-11-11
# 993                hapi-fhir-jpaserver-starter/trifork  forks  2021-10-07
# 994                 hapi-fhir-jpaserver-starter/jkiddo  forks  2021-02-21
# 995                       torinox-in-docker/fmotrifork  forks  2019-03-18
# 1000  fastlane-plugin-prepare_build_resources/bjarkehs  forks  2017-01-26
# 1016                         humio-android-logger/SDI8  forks  2016-11-16
# 1034                                 kitos/Strongminds  forks  2019-06-25
# 1035                                  kitos/miracle-as  forks  2016-05-03
# 1036                        kitos_frontend/Strongminds  forks  2023-01-03
# 1037                       P3AssetManagement/humleflue  forks  2021-04-23
# 1040                                   SimpleCare/hcnp  forks  2025-04-22
# 1216                             SVProgressHUD/trifork  forks  2018-07-06
# 1217                 pcf-reloader-transformer/madsthom  forks  2022-07-06
# 1253                        uni-notes/AndersSpringborg  forks  2020-05-31
# 2692                         humio-android-logger/SDI8  forks  2016-11-16
# 2711                      torinox-in-docker/fmotrifork  forks  2019-03-18
# 2840                           TIM-Android/LVH-trifork  forks  2022-11-22
# 2841                                   dgws/frjtrifork  forks  2012-05-10
# 2842                                    sdm/frjtrifork  forks  2012-03-02
# 2917                               the-vault/MadsPoder  forks  2019-09-16
# 3075                 TriforkSwiftExtensions/jhntrifork  forks  2018-10-04
# 3076                          SVProgressHUD/jhntrifork  forks  2018-07-06
# 3118                         TIM-Android/SebastianRask  forks  2023-03-15

# %% [markdown]
# # 2. Examining the networks

# %% [markdown]
# ## 2.1 Collaboration

# %%
result_trifork = look_company_up_in_edgelist(
    company='trifork', 
    edgelist=collaboration_edges_user_level, 
    direction='out', 
    exclude_self_loops=True
)
result_trifork
# Out:
#            src  target src_company target_company  src_company_category  \
# 967   madsthom  mkholt     trifork     delegateas                     1
# 1217  madsthom  mkholt     trifork     delegateas                     1
#
#                           src_company_label  target_company_category  \
# 967   1 Digital and marketing consultancies                        1
# 1217  1 Digital and marketing consultancies                        1
#
#                        target_company_label  d_intra_level  d_inter_level  \
# 967   1 Digital and marketing consultancies              0              1
# 1217  1 Digital and marketing consultancies              0              1
#
#                               edge_repo action  created_at
# 967   pcf-reloader-transformer/madsthom  forks  2022-07-06
# 1217  pcf-reloader-transformer/madsthom  forks  2022-07-06

# %% [markdown]
# ## 2.2 Attention

# %%
result_trifork = look_company_up_in_edgelist(
    company='trifork', 
    edgelist=attention_edges_user_level, 
    direction='all', 
    exclude_self_loops=False
)
result_trifork
# Out:
#                src   target src_company target_company  src_company_category  \
# 43      mfrtrifork  trifork     trifork        trifork                     1
# 44      frjtrifork  trifork     trifork        trifork                     1
# 45          jkiddo  trifork     trifork        trifork                     1
# 46          jkiddo  trifork     trifork        trifork                     1
# 47        bjarkehs  trifork     trifork        trifork                     1
# ...            ...      ...         ...            ...                   ...
# 3196          hcnp     hcnp     trifork        trifork                     1
# 3197          hcnp  trifork     trifork        trifork                     1
# 3198          hcnp     hcnp     trifork        trifork                     1
# 3199   twantrifork  trifork     trifork        trifork                     1
# 3200  aabl-trifork  trifork     trifork        trifork                     1
#
#                           src_company_label  target_company_category  \
# 43    1 Digital and marketing consultancies                        1
# 44    1 Digital and marketing consultancies                        1
# 45    1 Digital and marketing consultancies                        1
# 46    1 Digital and marketing consultancies                        1
# 47    1 Digital and marketing consultancies                        1
# ...                                     ...                      ...
# 3196  1 Digital and marketing consultancies                        1
# 3197  1 Digital and marketing consultancies                        1
# 3198  1 Digital and marketing consultancies                        1
# 3199  1 Digital and marketing consultancies                        1
# 3200  1 Digital and marketing consultancies                        1
#
#                        target_company_label  d_intra_level  d_inter_level  \
# 43    1 Digital and marketing consultancies              1              0
# 44    1 Digital and marketing consultancies              1              0
# 45    1 Digital and marketing consultancies              1              0
# 46    1 Digital and marketing consultancies              1              0
# 47    1 Digital and marketing consultancies              1              0
# ...                                     ...            ...            ...
# 3196  1 Digital and marketing consultancies              1              0
# 3197  1 Digital and marketing consultancies              1              0
# 3198  1 Digital and marketing consultancies              1              0
# 3199  1 Digital and marketing consultancies              1              0
# 3200  1 Digital and marketing consultancies              1              0
#
#                                              edge_repo   action  created_at
# 43                               AndroidBLE/mfrtrifork    stars  2014-02-23
# 44                                     dgws/frjtrifork    stars  2011-05-25
# 45                                         dgws/jkiddo    stars  2010-02-26
# 46                                       erjang/jkiddo    stars  2010-02-26
# 47    fastlane-plugin-prepare_build_resources/bjarkehs    stars  2012-09-04
# ...                                                ...      ...         ...
# 3196                      trireg2-import-clockify/hcnp  watches  2024-05-13
# 3197                                 ig-publisher/hcnp  watches  2024-05-16
# 3198                                  hello-world/hcnp  watches  2025-03-14
# 3199                                              None  follows  2010-07-02
# 3200                                              None  follows  2010-07-02
#
# [1165 rows x 13 columns]

# %% [markdown]
# # 3. Get number of followers

# %%
# Get all unique GitHub usernames from the edge list
unique_users = pd.concat([all_edges_user_level['src'], all_edges_user_level['target']]).unique()

def get_followers(username: str) -> int | None:
    """
    Returns the number of followers for a given GitHub username.
    If the user does not exist or is private, returns None.
    """
    try:
        user_obj = gs.get_user(username)
        if user_obj is None:
            print(f"[!] User '{username}' not found.")
            return None
        return user_obj.followers
    except Exception as e:
        print(f"[!] Error retrieving user '{username}': {e}")
        return None

# Query follower counts for all unique users
followers = {user: get_followers(user) for user in tqdm(unique_users)}
# Out:
#  18%|█▊        | 56/305 [00:25<01:59,  2.08it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 20
#      17         return None
#      19 # Query follower counts for all unique users
# ---> 20 followers = {user: get_followers(user) for user in tqdm(unique_users)}
#
# Cell In[7], line 20, in <dictcomp>(.0)
#      17         return None
#      19 # Query follower counts for all unique users
# ---> 20 followers = {user: get_followers(user) for user in tqdm(unique_users)}
#
# Cell In[7], line 10, in get_followers(username)
#       5 """
#       6 Returns the number of followers for a given GitHub username.
#       7 If the user does not exist or is private, returns None.
#       8 """
#       9 try:
# ---> 10     user_obj = gs.get_user(username)
#      11     if user_obj is None:
#      12         print(f"[!] User '{username}' not found.")
#
# File ~/Library/CloudStorage/OneDrive-UniversityofCopenhagen/2. SODAS/99 Asger old notebooks/Attention network/GH scrape for real 3/resources/github_functions.py:97, in ratelimiter.<locals>.wrapper(*args, **kwargs)
#      93         print(
#      94             f"Waiting {time_before_reset} seconds (or {round(time_before_reset/60, 2)} mins) for reseting of rates"
#      95         )
#      96         time.sleep(time_before_reset + 10)  # adding 10 seconds to be sure
# ---> 97 result = func(*args, **kwargs)
#      98 return result
#
# File ~/Library/CloudStorage/OneDrive-UniversityofCopenhagen/2. SODAS/99 Asger old notebooks/Attention network/GH scrape for real 3/resources/github_functions.py:241, in GithubScraper.get_user(self, user_login)
#     238 @ratelimiter
#     239 def get_user(self, user_login):
#     240     try:
# --> 241         user = self.github.get_user(user_login)
#     242         if user:
#     243             return user
#
# File ~/.local/share/uv/venvs/github/lib/python3.11/site-packages/github/MainClass.py:406, in Github.get_user(self, login)
#     403 url = f"/users/{login}"
#     404 # always return a completed NamedUser
#     405 # v3: remove complete() here and make this as lazy as github.Github is
# --> 406 return github.NamedUser.NamedUser(self.__requester, url=url).complete()
#
# File ~/.local/share/uv/venvs/github/lib/python3.11/site-packages/github/GithubObject.py:522, in CompletableGithubObject.__init__(self, requester, headers, attributes, completed, url, accept)
#     519 # complete this completable object when requester indicates non-laziness and
#     520 # neither of complete, headers and attributes are given
#     521 if requester.is_not_lazy and completed is None and not response_given:
# --> 522     self.complete()
#
# File ~/.local/share/uv/venvs/github/lib/python3.11/site-packages/github/GithubObject.py:538, in CompletableGithubObject.complete(self)
#     537 def complete(self) -> Self:
# --> 538     self._completeIfNeeded()
#     539     return self
#
# File ~/.local/share/uv/venvs/github/lib/python3.11/site-packages/github/GithubObject.py:547, in CompletableGithubObject._completeIfNeeded(self)
#     545 def _completeIfNeeded(self) -> None:
#     546     if not self.__completed:
# --> 547         self.__complete()
#
# File ~/.local/share/uv/venvs/github/lib/python3.11/site-packages/github/GithubObject.py:552, in CompletableGithubObject.__complete(self)
#     550 if self._url.value is None:
#     551     raise IncompletableObject(400, message="Cannot complete object as it contains no URL")
# --> 552 headers, data = self._requester.requestJsonAndCheck("GET", self._url.value, headers=self.__completeHeaders)
#     553 self._storeAndUseAttributes(headers, data)
#     554 self.__completed = True
#
# File ~/.local/share/uv/venvs/github/lib/python3.11/site-packages/github/Requester.py:625, in Requester.requestJsonAndCheck(self, verb, url, parameters, headers, input, follow_302_redirect)
#     606 def requestJsonAndCheck(
#     607     self,
#     608     verb: str,
#    (...)
#     613     follow_302_redirect: bool = False,
#     614 ) -> Tuple[Dict[str, Any], Any]:
#     615     """
#     616     Send a request with JSON body.
#     617
#    (...)
#     622
#     623     """
#     624     return self.__check(
# --> 625         *self.requestJson(
#     626             verb,
#     627             url,
#     628             parameters,
#     629             headers,
#     630             input,
#     631             self.__customConnection(url),
#     632             follow_302_redirect=follow_302_redirect,
#     633         )
#     634     )
#
# File ~/.local/share/uv/venvs/github/lib/python3.11/site-packages/github/Requester.py:959, in Requester.requestJson(self, verb, url, parameters, headers, input, cnx, follow_302_redirect)
#     956 def encode(input: Any) -> Tuple[str, str]:
#     957     return "application/json", json.dumps(input)
# --> 959 status, responseHeaders, output = self.__requestEncode(
#     960     cnx, verb, url, parameters, headers, input, encode, follow_302_redirect=follow_302_redirect
#     961 )
#     962 if isinstance(output, str):
#     963     return status, responseHeaders, output
#
# File ~/.local/share/uv/venvs/github/lib/python3.11/site-packages/github/Requester.py:1098, in Requester.__requestEncode(self, cnx, verb, url, parameters, requestHeaders, input, encode, stream, follow_302_redirect)
#    1094     requestHeaders["Content-Type"], encoded_input = encode(input)
#    1096 self.NEW_DEBUG_FRAME(requestHeaders)
# -> 1098 status, responseHeaders, output = self.__requestRaw(
#    1099     cnx, verb, url, requestHeaders, encoded_input, stream=stream, follow_302_redirect=follow_302_redirect
#    1100 )
#    1102 if Consts.headerRateRemaining in responseHeaders and Consts.headerRateLimit in responseHeaders:
#    1103     self.rate_limiting = (
#    1104         # ints expected but sometimes floats returned: https://github.com/PyGithub/PyGithub/pull/2697
#    1105         int(float(responseHeaders[Consts.headerRateRemaining])),
#    1106         int(float(responseHeaders[Consts.headerRateLimit])),
#    1107     )
#
# File ~/.local/share/uv/venvs/github/lib/python3.11/site-packages/github/Requester.py:1136, in Requester.__requestRaw(self, cnx, verb, url, requestHeaders, input, stream, follow_302_redirect)
#    1134     cnx = self.__createConnection()
#    1135 cnx.request(verb, url, input, requestHeaders, stream)
# -> 1136 response = cnx.getresponse()
#    1137 output = response if stream else response.read()
#    1138 status = response.status
#
# File ~/.local/share/uv/venvs/github/lib/python3.11/site-packages/github/Requester.py:214, in HTTPSRequestsConnectionClass.getresponse(self)
#     212 verb = getattr(self.session, self.verb.lower())
#     213 url = f"{self.protocol}://{self.host}:{self.port}{self.url}"
# --> 214 r = verb(
#     215     url,
#     216     headers=self.headers,
#     217     data=self.input,
#     218     timeout=self.timeout,
#     219     verify=self.verify,
#     220     allow_redirects=False,
#     221 )
#     222 return RequestsResponse(r)
#
# File ~/.local/share/uv/venvs/github/lib/python3.11/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/.local/share/uv/venvs/github/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.local/share/uv/venvs/github/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.local/share/uv/venvs/github/lib/python3.11/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/.local/share/uv/venvs/github/lib/python3.11/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/.local/share/uv/venvs/github/lib/python3.11/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
#     464     # Trigger any extra validation we need to do.
#     465     try:
# --> 466         self._validate_conn(conn)
#     467     except (SocketTimeout, BaseSSLError) as e:
#     468         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/.local/share/uv/venvs/github/lib/python3.11/site-packages/urllib3/connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1093 # Force connect early to allow us to validate the connection.
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1098 if not conn.is_verified and not conn.proxy_is_verified:
#
# File ~/.local/share/uv/venvs/github/lib/python3.11/site-packages/urllib3/connection.py:693, in HTTPSConnection.connect(self)
#     691 try:
#     692     sock: socket.socket | ssl.SSLSocket
# --> 693     self.sock = sock = self._new_conn()
#     694     server_hostname: str = self.host
#     695     tls_in_tls = False
#
# File ~/.local/share/uv/venvs/github/lib/python3.11/site-packages/urllib3/connection.py:199, in HTTPConnection._new_conn(self)
#     194 """Establish a socket connection and set nodelay settings on it.
#     195
#     196 :return: New socket connection.
#     197 """
#     198 try:
# --> 199     sock = connection.create_connection(
#     200         (self._dns_host, self.port),
#     201         self.timeout,
#     202         source_address=self.source_address,
#     203         socket_options=self.socket_options,
#     204     )
#     205 except socket.gaierror as e:
#     206     raise NameResolutionError(self.host, self, e) from e
#
# File ~/.local/share/uv/venvs/github/lib/python3.11/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      71 if source_address:
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#      75 err = None
#
# KeyboardInterrupt:

# %%
# Filter out users with no follower data (None)
valid_followers: Dict[str, int] = {k: v for k, v in followers.items() if v is not None}

# Sort users by number of followers (descending)
followers_sorted = dict(sorted(valid_followers.items(), key=lambda item: item[1], reverse=True))

# Print the top 20 users with the most followers
print("Top 20 users by follower count:\n")
for user, count in list(followers_sorted.items())[:20]:
    print(f"{user}: {count}")
# Out:
# Top 20 users by follower count:
#
# EG-A-S: 375
# kennylevinsen: 172
# thebuilder: 160
# trifork: 66
# jkiddo: 50
# jeme: 40
# shapehq: 40
# kawaiipantsu: 38
# AndersSpringborg: 26
# madsthom: 25
# bjarkehs: 21
# gugi9000: 20
# HusseinElZein: 20
# fredelundbeck: 18
# hcarreras: 17
# signifly: 17
# jacobe: 16
# TusharRoy23: 13
# mathiasandresen: 12
# anderslime: 12
