# %% [markdown]
# # 0. Importing packages

# %%
# Load the autoreload extension to automatically reload modules before executing code (to avoid restarting the kernel)
# %load_ext autoreload 
# NB. uncomment the line above first time you run this cell
# %autoreload 2

# %%
import json
import pandas as pd
from pathlib import Path

# Custom functions
import resources.filter_functions as filter

# %% [markdown]
# ## 0.1 File Paths

# %%
fp_main = Path('/Volumes/SAM-SODAS-DISTRACT/Coding Distraction/github_as_a_market_device')
fp_main_output = Path(fp_main / 'output')

# %% [markdown]
# # 1. Importing data

# %% [markdown]
# *Loading in first and second tier data*

# %%
# Opening the files
first_tier_file_name = "first_tier_ties_sorted.parquet.gzip"
second_tier_file_name = "second_tier_userinfo.jsonl"
fp_first_tier = fp_main_output / first_tier_file_name
fp_second_tier = fp_main_output / second_tier_file_name

# Load the first tier data
first_tier_data_clean = pd.read_parquet(fp_first_tier)

with open(fp_second_tier, 'r') as f:
    second_tier_list = [json.loads(line) for line in f]

# Type hint so Pylance can infer the type of the variable
second_tier_data: pd.DataFrame = pd.DataFrame(second_tier_list)

# %% [markdown]
# # 2. Resolve multiple matches

# %%
# Making a copy of the dataframe
second_tier_data_clean = second_tier_data.copy()

# Access output path
output_path = 'resolved_multicompany_cases.jsonl'

# Resolve multiple companies
second_tier_data_clean = filter.resolve_multiple_companies(
    second_tier_data,
    output_path=output_path,
)

# %% [markdown]
# # 3. Merging first-tier and second-tier

# %%
# Assign tier labels to each dataset
first_tier_data_clean['tier'] = 1
second_tier_data_clean['tier'] = 2

# Combine both tiers into a single dataframe
merged_users = pd.concat(
    [first_tier_data_clean, second_tier_data_clean],
    ignore_index=True
)
print(f"[INFO] Merged user data shape: {merged_users.shape}")

# Remove duplicate users based on GitHub login
unique_users_data = merged_users.drop_duplicates(subset='user_login').reset_index(drop=True)
print(f"[INFO] Deduplicated user data shape: {unique_users_data.shape}")
# Out:
# [INFO] Merged user data shape: (238, 21)
# [INFO] Deduplicated user data shape: (228, 21)

# %%
merged_users
# Out:
#          user_login search_with_company listed_company inferred_company  \
# 0          NodesAMS               nodes   Nodes Agency            nodes
# 1    nodes-checkout               nodes       Nodes.dk            nodes
# 2        nodes-team               nodes   Nodes Agency            nodes
# 3            abtion              abtion           None           abtion
# 4         hcarreras              abtion         Abtion           abtion
# ..              ...                 ...            ...              ...
# 233      tfctrifork             trifork        Trifork          trifork
# 234            hcnp             trifork       @trifork          trifork
# 235     twantrifork             trifork       @trifork          trifork
# 236    aabl-trifork             trifork        Trifork          trifork
# 237   barbararcbf12       charlie tango  Charlie Tango    charlie tango
#
#                                matched_company_strings      usertype  \
# 0    {'abtion': None, 'capgemini': None, 'charlie t...          User
# 1    {'abtion': None, 'capgemini': None, 'charlie t...          User
# 2    {'abtion': None, 'capgemini': None, 'charlie t...          User
# 3    {'abtion': ['abtion', 'iwanttowork@abtion.com'...  Organization
# 4    {'abtion': ['abtion', 'hc@abtion.com', 'abtion...          User
# ..                                                 ...           ...
# 233  {'trifork': ['tfctrifork', 'trifork', 'tfc@tri...          User
# 234                          {'trifork': ['@trifork']}          User
# 235           {'trifork': ['twantrifork', '@trifork']}          User
# 236           {'trifork': ['aabl-trifork', 'trifork']}          User
# 237               {'charlie tango': ['charlie tango']}          User
#
#                       email                           location  \
# 0                      None                              [CPH]
# 1               cw@nodes.dk  [dk, dk, dk, Copenhagen, Denmark]
# 2                      None                       [Copenhagen]
# 3    iwanttowork@abtion.com                       [Copenhagen]
# 4             hc@abtion.com                       [Copenhagen]
# ..                      ...                                ...
# 233         tfc@trifork.com                  [Aarhus, Denmark]
# 234                    None                  [Aarhus, Denmark]
# 235                    None                          [Aalborg]
# 236                    None                           [Aarhus]
# 237                    None              [Copenhagen, Denmark]
#
#                                           bio  \
# 0    Nodes \r\nApplication Management Service
# 1                                        None
# 2                                        None
# 3                  Not another digital agency
# 4                                        None
# ..                                        ...
# 233                                      None
# 234                                      None
# 235                                      None
# 236                                      None
# 237                                      None
#
#                                           blog  ...  \
# 0                  https://www.nodesagency.com  ...
# 1                         http://www.nodes.dk/  ...
# 2                       http://nodesagency.com  ...
# 3                           https://abtion.com  ...
# 4                                   abtion.com  ...
# ..                                         ...  ...
# 233                                             ...
# 234                                             ...
# 235                                             ...
# 236                                             ...
# 237  https://barbaraferreirasite.wordpress.com  ...
#
#                                             follows_in  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3    [{'created_at': '2014-01-12', 'owner_login': '...
# 4    [{'created_at': '2009-07-02', 'owner_login': '...
# ..                                                 ...
# 233                                                 []
# 234  [{'repo_name': None, 'owner_login': 'ask0ldd',...
# 235                                                 []
# 236                                                 []
# 237  [{'repo_name': None, 'owner_login': 'odGit', '...
#
#                                            follows_out  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4    [{'created_at': '2008-03-31', 'owner_login': '...
# ..                                                 ...
# 233                                                 []
# 234  [{'repo_name': None, 'owner_login': 'kjuulh', ...
# 235  [{'repo_name': None, 'owner_login': 'trifork',...
# 236  [{'repo_name': None, 'owner_login': 'trifork',...
# 237  [{'repo_name': None, 'owner_login': 'stolinski...
#
#                                             watches_in  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3    [{'created_at': '2012-02-23', 'owner_login': '...
# 4    [{'created_at': '2014-11-04', 'owner_login': '...
# ..                                                 ...
# 233  [{'repo_name': 'PorscheLeMansVP', 'owner_login...
# 234  [{'repo_name': 'implementation-guide', 'owner_...
# 235                                                 []
# 236                                                 []
# 237  [{'repo_name': 'trivia-app', 'owner_login': 'b...
#
#                                            watches_out  \
# 0                                                   []
# 1    [{'created_at': '2015-01-29', 'owner_login': '...
# 2    [{'created_at': '2016-03-27', 'owner_login': '...
# 3                                                   []
# 4    [{'created_at': '2010-10-26', 'owner_login': '...
# ..                                                 ...
# 233  [{'repo_name': 'TriforkSwiftExtensions', 'owne...
# 234  [{'repo_name': 'trireg2-import-clockify', 'own...
# 235                                                 []
# 236                                                 []
# 237  [{'repo_name': 'eslint-config-charlie-tango', ...
#
#                                               stars_in  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3    [{'created_at': '2015-08-26', 'owner_login': '...
# 4    [{'created_at': '2014-01-01', 'owner_login': '...
# ..                                                 ...
# 233                                                 []
# 234  [{'repo_name': 'implementation-guide', 'owner_...
# 235                                                 []
# 236                                                 []
# 237  [{'repo_name': 'react-redux-video-library', 'o...
#
#                                              stars_out  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4    [{'created_at': '2018-05-31', 'owner_login': '...
# ..                                                 ...
# 233                                                 []
# 234  [{'repo_name': 'dagger', 'owner_login': 'dagge...
# 235                                                 []
# 236  [{'repo_name': 'ai-testimonials', 'owner_login...
# 237  [{'repo_name': 'pokemon-react-ts-gql', 'owner_...
#
#                                               forks_in  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3    [{'created_at': '2025-05-05', 'owner_login': '...
# 4    [{'created_at': '2015-05-06', 'owner_login': '...
# ..                                                 ...
# 233                                                 []
# 234  [{'repo_name': 'implementation-guide', 'owner_...
# 235                                                 []
# 236                                                 []
# 237  [{'repo_name': 'animated-movie-library', 'owne...
#
#                                              forks_out  \
# 0    [{'created_at': '2022-10-14', 'owner_login': '...
# 1                                                   []
# 2                                                   []
# 3    [{'created_at': '2020-12-10', 'owner_login': '...
# 4    [{'created_at': '2018-04-13', 'owner_login': '...
# ..                                                 ...
# 233                                                 []
# 234  [{'repo_name': 'db-operator-charts', 'owner_lo...
# 235                                                 []
# 236  [{'repo_name': 'smallrye-mutiny', 'owner_login...
# 237  [{'repo_name': 'advanced-react-hooks', 'owner_...
#
#                                            unique_ties tier
# 0                                      [ml-opensource]    1
# 1                                         [ml-archive]    1
# 2                                         [ml-archive]    1
# 3    [Dynastig, magnusfriis, jeppester, djuric, Ale...    1
# 4    [Citizen2028, apneadiving, IanAbildskou, LoneK...    1
# ..                                                 ...  ...
# 233                                                NaN    2
# 234                                                NaN    2
# 235                                                NaN    2
# 236                                                NaN    2
# 237                                                NaN    2
#
# [238 rows x 21 columns]

# %% [markdown]
# # 4. Output file

# %%
# Output the filtered users
unique_users_data.to_parquet(fp_main_output / 'unique_users_first_second.gzip.parquet')
